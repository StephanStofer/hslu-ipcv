# %% [markdown]
# # Exercise 10: Convolutional neural network
#
# In this exercise, we will look at an introduction of classifying images using deep convolutional neural networks.
#
# Training convolutional networks on many images can be quite time consuming. We use the same small standard dataset from last weeks exercise. I tgives a good introduction to the topic and is available in Keras.
#
# The CIFAR-10 data set consists of 50000 training and 10000 test images of size 32x32 labelled into 10 classes. See also https://keras.io/datasets/#cifar10-small-image-classification

# %%
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3330                 else:
# -> 3331                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3332             finally:
#
# <ipython-input-1-fcbc117d9031> in <module>
#       4 import numpy as np
# ----> 5 import tensorflow as tf
#       6 from tensorflow import keras
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in <module>
#     100 # We still need all the names that are toplevel on tensorflow_core
# --> 101 from tensorflow_core import *
#     102
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/__init__.py in <module>
#      39
# ---> 40 from tensorflow.python.tools import module_util as _module_util
#      41
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/__init__.py in <module>
#      63 # Protocol buffers
# ---> 64 from tensorflow.core.framework.graph_pb2 import *
#      65 from tensorflow.core.framework.node_def_pb2 import *
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/core/framework/graph_pb2.py in <module>
#       6 _b=sys.version_info[0]<3 and (lambda x:x) or (lambda x:x.encode('latin1'))
# ----> 7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import message as _message
#
# ~/Library/Python/3.7/lib/python/site-packages/google/protobuf/__init__.py in <module>
#      36   try:
# ---> 37     __import__('pkg_resources').declare_namespace(__name__)
#      38   except ImportError:
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/__init__.py in <module>
#      83 __import__('pkg_resources.extern.packaging.specifiers')
# ---> 84 __import__('pkg_resources.extern.packaging.requirements')
#      85 __import__('pkg_resources.extern.packaging.markers')
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/packaging/requirements.py in <module>
#       8
# ----> 9 from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#      10 from pkg_resources.extern.pyparsing import ZeroOrMore, Word, Optional, Regex, Combine
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/extern/__init__.py in load_module(self, fullname)
#      42                 extant = prefix + target
# ---> 43                 __import__(extant)
#      44                 mod = sys.modules[extant]
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in <module>
#    4755
# -> 4756 _escapedPunc = Word( _bslash, r"\[]-*.$+^?()~ ", exact=2 ).setParseAction(lambda s,l,t:t[0][1])
#    4757 _escapedHexChar = Regex(r"\\0?[xX][0-9a-fA-F]+").setParseAction(lambda s,l,t:unichr(int(t[0].lstrip(r'\0x'),16)))
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in setParseAction(self, *fns, **kwargs)
#    1283         """
# -> 1284         self.parseAction = list(map(_trim_arity, list(fns)))
#    1285         self.callDuringTry = kwargs.get("callDuringTry", False)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in _trim_arity(func, maxargs)
#    1065     # THE CALL TO FUNC INSIDE WRAPPER, LINE_DIFF MUST BE MODIFIED!!!!
# -> 1066     this_line = extract_stack(limit=2)[-1]
#    1067     pa_call_line_synth = (this_line[0], this_line[1]+LINE_DIFF)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in extract_stack(limit)
#    1049             offset = -3 if system_version == (3,5,0) else -2
# -> 1050             frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#    1051             return [frame_summary[:2]]
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract_stack(f, limit)
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      47         if module_globals is None:
# ---> 48             for mod in sys.modules.values():
#      49                 if getattr(mod, '__file__', None) == filename:
#
# RuntimeError: dictionary changed size during iteration
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'RuntimeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1150             # (5 blanks lines) where none should be returned.
# -> 1151             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1152         except UnicodeDecodeError:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     318         try:
# --> 319             return f(*args, **kwargs)
#     320         finally:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     352
# --> 353     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     354     # If the error is at the console, don't build any context, since it would
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getinnerframes(tb, context)
#    1501     while tb:
# -> 1502         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1503         framelist.append(FrameInfo(*frameinfo))
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1459
# -> 1460     filename = getsourcefile(frame) or getfile(frame)
#    1461     if context > 0:
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getsourcefile(object)
#     695     # only return a non-existent filename if the module has a PEP 302 loader
# --> 696     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     697         return filename
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getmodule(object, _filename)
#     732     for modname, module in list(sys.modules.items()):
# --> 733         if ismodule(module) and hasattr(module, '__file__'):
#     734             f = module.__file__
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/__init__.py in <module>
#      41
# ---> 42 from . _api.v2 import audio
#      43 from . _api.v2 import autodiff
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/_api/v2/audio/__init__.py in <module>
#       9
# ---> 10 from tensorflow.python.ops.gen_audio_ops import decode_wav
#      11 from tensorflow.python.ops.gen_audio_ops import encode_wav
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/ops/gen_audio_ops.py in <module>
#       9 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 10 from tensorflow.python.eager import context as _context
#      11 from tensorflow.python.eager import core as _core
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/context.py in <module>
#      28
# ---> 29 from tensorflow.core.protobuf import config_pb2
#      30 from tensorflow.core.protobuf import rewriter_config_pb2
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/core/protobuf/config_pb2.py in <module>
#       6 _b=sys.version_info[0]<3 and (lambda x:x) or (lambda x:x.encode('latin1'))
# ----> 7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import message as _message
#
# ~/Library/Python/3.7/lib/python/site-packages/google/protobuf/__init__.py in <module>
#      36   try:
# ---> 37     __import__('pkg_resources').declare_namespace(__name__)
#      38   except ImportError:
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/__init__.py in <module>
#      83 __import__('pkg_resources.extern.packaging.specifiers')
# ---> 84 __import__('pkg_resources.extern.packaging.requirements')
#      85 __import__('pkg_resources.extern.packaging.markers')
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/packaging/requirements.py in <module>
#       8
# ----> 9 from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#      10 from pkg_resources.extern.pyparsing import ZeroOrMore, Word, Optional, Regex, Combine
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/extern/__init__.py in load_module(self, fullname)
#      42                 extant = prefix + target
# ---> 43                 __import__(extant)
#      44                 mod = sys.modules[extant]
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in <module>
#    4755
# -> 4756 _escapedPunc = Word( _bslash, r"\[]-*.$+^?()~ ", exact=2 ).setParseAction(lambda s,l,t:t[0][1])
#    4757 _escapedHexChar = Regex(r"\\0?[xX][0-9a-fA-F]+").setParseAction(lambda s,l,t:unichr(int(t[0].lstrip(r'\0x'),16)))
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in setParseAction(self, *fns, **kwargs)
#    1283         """
# -> 1284         self.parseAction = list(map(_trim_arity, list(fns)))
#    1285         self.callDuringTry = kwargs.get("callDuringTry", False)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in _trim_arity(func, maxargs)
#    1065     # THE CALL TO FUNC INSIDE WRAPPER, LINE_DIFF MUST BE MODIFIED!!!!
# -> 1066     this_line = extract_stack(limit=2)[-1]
#    1067     pa_call_line_synth = (this_line[0], this_line[1]+LINE_DIFF)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in extract_stack(limit)
#    1049             offset = -3 if system_version == (3,5,0) else -2
# -> 1050             frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#    1051             return [frame_summary[:2]]
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract_stack(f, limit)
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      47         if module_globals is None:
# ---> 48             for mod in sys.modules.values():
#      49                 if getattr(mod, '__file__', None) == filename:
#
# RuntimeError: dictionary changed size during iteration
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3253                         asy = compare(code)
# -> 3254                     if (await self.run_code(code, result,  async_=asy)):
#    3255                         return True
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3347                 result.error_in_exec = sys.exc_info()[1]
# -> 3348             self.showtraceback(running_compiled_code=True)
#    3349         else:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1417         return FormattedTB.structured_traceback(
# -> 1418             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1419
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1317             return VerboseTB.structured_traceback(
# -> 1318                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1319             )
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1174         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1175                                                                tb_offset)
#    1176
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1126         head = self.prepare_header(etype, self.long_header)
# -> 1127         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1128
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1165             inspect_error()
# -> 1166             traceback.print_exc(file=self.ostream)
#    1167             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in print_exc(limit, file, chain)
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     103     for line in TracebackException(
# --> 104             type(value), value, tb, limit=limit).format(chain=chain):
#     105         print(line, file=file, end="")
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     507             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
# --> 508             capture_locals=capture_locals)
#     509         self.exc_type = exc_type
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      48             for mod in sys.modules.values():
# ---> 49                 if getattr(mod, '__file__', None) == filename:
#      50                     module_globals = mod.__dict__
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/__init__.py in <module>
#      41
# ---> 42 from . _api.v2 import audio
#      43 from . _api.v2 import autodiff
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/_api/v2/audio/__init__.py in <module>
#       9
# ---> 10 from tensorflow.python.ops.gen_audio_ops import decode_wav
#      11 from tensorflow.python.ops.gen_audio_ops import encode_wav
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/ops/gen_audio_ops.py in <module>
#       9 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 10 from tensorflow.python.eager import context as _context
#      11 from tensorflow.python.eager import core as _core
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/context.py in <module>
#      28
# ---> 29 from tensorflow.core.protobuf import config_pb2
#      30 from tensorflow.core.protobuf import rewriter_config_pb2
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/core/protobuf/config_pb2.py in <module>
#       6 _b=sys.version_info[0]<3 and (lambda x:x) or (lambda x:x.encode('latin1'))
# ----> 7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import message as _message
#
# ~/Library/Python/3.7/lib/python/site-packages/google/protobuf/__init__.py in <module>
#      36   try:
# ---> 37     __import__('pkg_resources').declare_namespace(__name__)
#      38   except ImportError:
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/__init__.py in <module>
#      83 __import__('pkg_resources.extern.packaging.specifiers')
# ---> 84 __import__('pkg_resources.extern.packaging.requirements')
#      85 __import__('pkg_resources.extern.packaging.markers')
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/packaging/requirements.py in <module>
#       8
# ----> 9 from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#      10 from pkg_resources.extern.pyparsing import ZeroOrMore, Word, Optional, Regex, Combine
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/extern/__init__.py in load_module(self, fullname)
#      42                 extant = prefix + target
# ---> 43                 __import__(extant)
#      44                 mod = sys.modules[extant]
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in <module>
#    4755
# -> 4756 _escapedPunc = Word( _bslash, r"\[]-*.$+^?()~ ", exact=2 ).setParseAction(lambda s,l,t:t[0][1])
#    4757 _escapedHexChar = Regex(r"\\0?[xX][0-9a-fA-F]+").setParseAction(lambda s,l,t:unichr(int(t[0].lstrip(r'\0x'),16)))
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in setParseAction(self, *fns, **kwargs)
#    1283         """
# -> 1284         self.parseAction = list(map(_trim_arity, list(fns)))
#    1285         self.callDuringTry = kwargs.get("callDuringTry", False)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in _trim_arity(func, maxargs)
#    1065     # THE CALL TO FUNC INSIDE WRAPPER, LINE_DIFF MUST BE MODIFIED!!!!
# -> 1066     this_line = extract_stack(limit=2)[-1]
#    1067     pa_call_line_synth = (this_line[0], this_line[1]+LINE_DIFF)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in extract_stack(limit)
#    1049             offset = -3 if system_version == (3,5,0) else -2
# -> 1050             frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#    1051             return [frame_summary[:2]]
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract_stack(f, limit)
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      47         if module_globals is None:
# ---> 48             for mod in sys.modules.values():
#      49                 if getattr(mod, '__file__', None) == filename:
#
# RuntimeError: dictionary changed size during iteration
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'RuntimeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1150             # (5 blanks lines) where none should be returned.
# -> 1151             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1152         except UnicodeDecodeError:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     318         try:
# --> 319             return f(*args, **kwargs)
#     320         finally:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     352
# --> 353     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     354     # If the error is at the console, don't build any context, since it would
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getinnerframes(tb, context)
#    1501     while tb:
# -> 1502         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1503         framelist.append(FrameInfo(*frameinfo))
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1459
# -> 1460     filename = getsourcefile(frame) or getfile(frame)
#    1461     if context > 0:
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getsourcefile(object)
#     695     # only return a non-existent filename if the module has a PEP 302 loader
# --> 696     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     697         return filename
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in getmodule(object, _filename)
#     732     for modname, module in list(sys.modules.items()):
# --> 733         if ismodule(module) and hasattr(module, '__file__'):
#     734             f = module.__file__
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/__init__.py in <module>
#      41
# ---> 42 from . _api.v2 import audio
#      43 from . _api.v2 import autodiff
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/_api/v2/audio/__init__.py in <module>
#       9
# ---> 10 from tensorflow.python.ops.gen_audio_ops import decode_wav
#      11 from tensorflow.python.ops.gen_audio_ops import encode_wav
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/ops/gen_audio_ops.py in <module>
#       9 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 10 from tensorflow.python.eager import context as _context
#      11 from tensorflow.python.eager import core as _core
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/context.py in <module>
#      28
# ---> 29 from tensorflow.core.protobuf import config_pb2
#      30 from tensorflow.core.protobuf import rewriter_config_pb2
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/core/protobuf/config_pb2.py in <module>
#       6 _b=sys.version_info[0]<3 and (lambda x:x) or (lambda x:x.encode('latin1'))
# ----> 7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import message as _message
#
# ~/Library/Python/3.7/lib/python/site-packages/google/protobuf/__init__.py in <module>
#      36   try:
# ---> 37     __import__('pkg_resources').declare_namespace(__name__)
#      38   except ImportError:
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/__init__.py in <module>
#      83 __import__('pkg_resources.extern.packaging.specifiers')
# ---> 84 __import__('pkg_resources.extern.packaging.requirements')
#      85 __import__('pkg_resources.extern.packaging.markers')
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/packaging/requirements.py in <module>
#       8
# ----> 9 from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#      10 from pkg_resources.extern.pyparsing import ZeroOrMore, Word, Optional, Regex, Combine
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/extern/__init__.py in load_module(self, fullname)
#      42                 extant = prefix + target
# ---> 43                 __import__(extant)
#      44                 mod = sys.modules[extant]
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in <module>
#    4755
# -> 4756 _escapedPunc = Word( _bslash, r"\[]-*.$+^?()~ ", exact=2 ).setParseAction(lambda s,l,t:t[0][1])
#    4757 _escapedHexChar = Regex(r"\\0?[xX][0-9a-fA-F]+").setParseAction(lambda s,l,t:unichr(int(t[0].lstrip(r'\0x'),16)))
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in setParseAction(self, *fns, **kwargs)
#    1283         """
# -> 1284         self.parseAction = list(map(_trim_arity, list(fns)))
#    1285         self.callDuringTry = kwargs.get("callDuringTry", False)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in _trim_arity(func, maxargs)
#    1065     # THE CALL TO FUNC INSIDE WRAPPER, LINE_DIFF MUST BE MODIFIED!!!!
# -> 1066     this_line = extract_stack(limit=2)[-1]
#    1067     pa_call_line_synth = (this_line[0], this_line[1]+LINE_DIFF)
#
# ~/Library/Python/3.7/lib/python/site-packages/pkg_resources/_vendor/pyparsing.py in extract_stack(limit)
#    1049             offset = -3 if system_version == (3,5,0) else -2
# -> 1050             frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#    1051             return [frame_summary[:2]]
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract_stack(f, limit)
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      47         if module_globals is None:
# ---> 48             for mod in sys.modules.values():
#      49                 if getattr(mod, '__file__', None) == filename:
#
# RuntimeError: dictionary changed size during iteration
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures)
#    3061
#    3062                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# -> 3063                        interactivity=interactivity, compiler=compiler, result=result)
#    3064
#    3065                 self.last_execution_succeeded = not has_raised
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3271             if result:
#    3272                 result.error_before_exec = sys.exc_info()[1]
# -> 3273             self.showtraceback()
#    3274             return True
#    3275
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1416             self.tb = tb
#    1417         return FormattedTB.structured_traceback(
# -> 1418             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1419
#    1420
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1316             # Verbose modes need a full traceback
#    1317             return VerboseTB.structured_traceback(
# -> 1318                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1319             )
#    1320         elif mode == 'Minimal':
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1173
#    1174         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1175                                                                tb_offset)
#    1176
#    1177         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1125         tb_offset = self.tb_offset if tb_offset is None else tb_offset
#    1126         head = self.prepare_header(etype, self.long_header)
# -> 1127         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1128
#    1129         if records is None:
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1164             # reproduce the problem.
#    1165             inspect_error()
# -> 1166             traceback.print_exc(file=self.ostream)
#    1167             info('\nUnfortunately, your original traceback can not be constructed.\n')
#    1168             return None
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in print_exc(limit, file, chain)
#     161 def print_exc(limit=None, file=None, chain=True):
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#     165 def format_exc(limit=None, chain=True):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     102         file = sys.stderr
#     103     for line in TracebackException(
# --> 104             type(value), value, tb, limit=limit).format(chain=chain):
#     105         print(line, file=file, end="")
#     106
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     506         self.stack = StackSummary.extract(
#     507             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
# --> 508             capture_locals=capture_locals)
#     509         self.exc_type = exc_type
#     510         # Capture now to permit freeing resources: only complication is in the
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     361         if lookup_lines:
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#     365
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/traceback.py in line(self)
#     283     def line(self):
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#     287
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      47         if module_globals is None:
#      48             for mod in sys.modules.values():
# ---> 49                 if getattr(mod, '__file__', None) == filename:
#      50                     module_globals = mod.__dict__
#      51                     break
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      48
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#      52
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      42   def _load(self):
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#      46     self.__dict__.update(module.__dict__)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/__init__.py in <module>
#      40 from tensorflow.python.tools import module_util as _module_util
#      41
# ---> 42 from . _api.v2 import audio
#      43 from . _api.v2 import autodiff
#      44 from . _api.v2 import autograph
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/_api/v2/audio/__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow.python.ops.gen_audio_ops import decode_wav
#      11 from tensorflow.python.ops.gen_audio_ops import encode_wav
#      12
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/ops/gen_audio_ops.py in <module>
#       8
#       9 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 10 from tensorflow.python.eager import context as _context
#      11 from tensorflow.python.eager import core as _core
#      12 from tensorflow.python.eager import execute as _execute
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/context.py in <module>
#      30 from tensorflow.core.protobuf import rewriter_config_pb2
#      31 from tensorflow.python import pywrap_tensorflow
# ---> 32 from tensorflow.python import tf2
#      33 from tensorflow.python.eager import executor
#      34 from tensorflow.python.eager import monitoring
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in __getattr__(self, item)
#      48
#      49   def __getattr__(self, item):
# ---> 50     module = self._load()
#      51     return getattr(module, item)
#      52
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/__init__.py in _load(self)
#      42   def _load(self):
#      43     """Import the target module and insert it into the parent's namespace."""
# ---> 44     module = _importlib.import_module(self.__name__)
#      45     self._parent_module_globals[self._local_name] = module
#      46     self.__dict__.update(module.__dict__)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/__init__.py in <module>
#     146
#     147 # Eager execution
# --> 148 from tensorflow.python.eager.context import executing_eagerly
#     149 from tensorflow.python.eager.remote import connect_to_remote_host
#     150 from tensorflow.python.eager.def_function import function
#
# ImportError: cannot import name 'executing_eagerly' from 'tensorflow.python.eager.context' (/Users/stofers/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/context.py)

# %% [markdown]
# Get the datasets if you did not load them last week. Some people experienced problems with loading directly from keras, if that did not work, you can also use the function below which uses http instead of https.

# %%
# the keras routines below might generate a ssl error inside jupyter notebooks
#
# (x_train, y_train_label), (x_test, y_test_label) = cifar10.load_data()
# 

# this is the same code, but using http instead of https
from tensorflow.python.keras.datasets.cifar import load_batch

def load_cifar_data():
    """Loads CIFAR10 dataset.
    # Returns
        Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
    """
    dirname = 'cifar-10-batches-py'
    origin = 'http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
    path = keras.utils.get_file(dirname, origin=origin, untar=True)

    num_train_samples = 50000

    x_train = np.empty((num_train_samples, 3, 32, 32), dtype='uint8')
    y_train = np.empty((num_train_samples,), dtype='uint8')

    for i in range(1, 6):
        fpath = os.path.join(path, 'data_batch_' + str(i))
        (x_train[(i - 1) * 10000: i * 10000, :, :, :],
         y_train[(i - 1) * 10000: i * 10000]) = load_batch(fpath)

    fpath = os.path.join(path, 'test_batch')
    x_test, y_test = load_batch(fpath)

    y_train = np.reshape(y_train, (len(y_train), 1))
    y_test = np.reshape(y_test, (len(y_test), 1))

    if K.image_data_format() == 'channels_last':
        x_train = x_train.transpose(0, 2, 3, 1)
        x_test = x_test.transpose(0, 2, 3, 1)

    return (x_train, y_train), (x_test, y_test)

# %%
(x_image_train, y_train_label), (x_image_test, y_test_label) = cifar10.load_data()
print(x_image_train.shape)
print(y_train_label.shape)

# %% [markdown]
# Let us look at some of the training images. The images contain 10 different classes.

# %%
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
def show_images(images, labels):
    fig, axes = plt.subplots(3, 5)
    fig.subplots_adjust(hspace=0.6, wspace=0.3)
    
    for i, ax in enumerate(axes.flat):
        # Plot image.
        example = np.random.randint(len(images))
        ax.imshow(images[example])
        
        # Name of the true class.
        cls_true_name = label_names[labels[example, 0]]
        xlabel = "{0}".format(cls_true_name)
        
        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    return

# %%
show_images(x_image_train, y_train_label)

# %% [markdown]
# In order to compute the loss function (cross entropy) the label data set must be one-hot encoded (also called categorical data)

# %%
num_classes = 10
y_train = keras.utils.to_categorical(y_train_label)
y_test = keras.utils.to_categorical(y_test_label)

# %% [markdown]
# ### Preprocessing
#
# Any input to a neural network should be normalized. For images this could be done per image (which would also normalize contrast) or just adjust the range globally. Normalization should either be so that the data is between 0 and 1 or (even better) between -1 and 1.

# %%
x_train = (2.0 * x_image_train.astype(np.float32) / 255.0) - 1.0
x_test = (2.0 * x_image_test.astype(np.float32) / 255.0) - 1.0
print(np.min(x_train), np.max(x_train))

# %% [markdown]
# The following code calculates a simple convolutional network.
#
# For image classification, we want to have some convolutional layers, some padding and probably at the end some dense (fully connected) layers.
#
# The last layer needs softmax as activation function for the correct number of classes.

# %%
def build_model_1():
    model = keras.Sequential()
    
    # add input shape
    model.add(keras.layers.Layer(input_shape=(32, 32, 3)))
    
    # add convolutional and pooling layers first
    model.add(keras.layers.Conv2D(32,3, padding='valid', activation='relu'))
    # add a pooling layer and another  convolutional layer here
    model.add(keras.layers.Conv2D(32,3, padding='valid', activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(32,3, padding='valid', activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    
    
    # add dense layers (need to flatten the input first)
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(128, activation='relu'))
  
    # add the last layer for the number of classes and using softmax
    model.add(keras.layers.Dense(10, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy'])
    return model

# %%
model = build_model_1()

# %%
model.summary()

# %%
history = model.fit(x_train, y_train, epochs=2, batch_size=128, validation_data=(x_test, y_test))

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Val'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend(['Train', 'Val'], loc='upper left')

# %%
model.summary()

# %% [markdown]
# ### Going further with the model
#
# Even a very simple network gets some decent results. From here we can go further using deeper networks and additional features.
#
# Try the following:
# - Train for more episodes
# - Make the network deeper by adding more layers
# - Increase the capacity by adding more nodes per layer
# - add regularization
# - add dropout
#
# Convolutional networks benefit from using GPU resources. Google provides a jupyter notebook environment with GPU support: https://colab.research.google.com
#
# This jupyter notebook should run as it is in that environment. To actually get a GPU you have to change the runtime type in the menu 'Runtime'
#
# When building new models, I usually like to keep the old ones for comparison, so I would recommend defining a new function for the new model.

# %%
def build_model_2():
     model = keras.Sequential()
     # todo
     return model

# %% [markdown]
# ### Optimization
#
# Keras supports different optimization models to use in model.compile, see https://keras.io/optimizers/.
#
# - Try different parameters for the SGD like initial learning rate and decay.
# - Try some of the oder popular optimization functions, like RMSprop, AdaGrad and Adam
